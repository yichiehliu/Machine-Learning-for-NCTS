# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import math

x = np.linspace(-20,20, 100)
#Loss function
y = (x+15)*(x*2-52)*(x*3-45)*(x*15-12) 
plt.plot(x, y)
plt.title('Loss Function')
# Out:
# Text(0.5,1,'Loss Function')
